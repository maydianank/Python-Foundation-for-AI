# %% [markdown]
# <a href="https://colab.research.google.com/github/maydianank/Python-Foundation-for-AI/blob/main/Day_1_Working_with_Variables_in_Python_to_Manage_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## PRINTING PRACTICE
#1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.
#2. Knead the dough for 10 minutes.
#3. Add 3g of Salt.
#4. Leave to rise for 2 hours.
#5. Bake at 200 degrees C for 30 minutes.

print("1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.")
print("2. Knead the dough for 10 minutes.")
print("3. Add 3g of Salt.")
print("4. Leave to rise for 2 hours.")
print("5. Bake at 200 degrees C for 30 minutes.")
# Out:
# 1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.
# 2. Knead the dough for 10 minutes.
# 3. Add 3g of Salt.
# 4. Leave to rise for 2 hours.
# 5. Bake at 200 degrees C for 30 minutes.

# %%
## Learn to use string concatenate and new line escape sequence. Use \n to add another line


#1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.
#2. Knead the dough for 10 minutes.
#3. Add 3g of Salt.
#4. Leave to rise for 2 hours.
#5. Bake at 200 degrees C for 30 minutes.

print("1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.\n2. Knead the dough for 10 minutes.\n3. Add 3g of Salt.\n4. Leave to rise for 2 hours.\n5. Bake at 200 degrees C for 30 minutes.")
# Out:
# 1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.
# 2. Knead the dough for 10 minutes.
# 3. Add 3g of Salt.
# 4. Leave to rise for 2 hours.
# 5. Bake at 200 degrees C for 30 minutes.

# %%
## Add a space between the strings

print("Hello "+ "Maydiana")
print("Hello" + " " + "Maydiana")
# Out:
# Hello Maydiana
# Hello Maydiana

# %%
## Learning How to use the Python input() fuction to collect user input and use it within your code
input("What's your Fullname?")
# Out:
# What's your Fullname?Maydiana Nurul
# 'Maydiana Nurul'

# %%
## Update the code to add an axclamation mark

print("Hello " + input("What's your Fullname?") + "！")
# Out:
# What's your Fullname?Maydiana Nurul
# Hello Maydiana Nurul！

# %%
## Learn to store values in contaoners for later uses

pet = input("What's your pet's name?")
print(pet)

pet = "Shiro"
print(pet)
# Out:
# What's your pet's name?Haruka Chealsea
# Haruka Chealsea
# Shiro

# %%
## Check the length of String

print(len(input("What is your cat's name?")))
# Out:
# What is your cat's name?Haruka Chealsea
# 15

# %%
cat = input("What is your cat's name?")
length = len(cat)
print(length)
# Out:
# What is your cat's name?Haruka Chealsea
# 15

# %%
## Learn the rule of Variable naming in Python
cat_name = "Shiro"
length_cat_name = len(cat_name)
print(length_cat_name)
# Out:
# 5

# %%
## Final Project "The Band Name Generator"

print("Welcome to the Band Name Generator.")
city = input("What is the name of the city you grew up in")
print(city)
pet = input("What's your pet's name")
print(pet)
print("Your band name could be " + city+ " " + pet)
# Out:
# Welcome to the Band Name Generator.
# What is the name of the city you grew up inKlaten
# Klaten
# What's your pet's nameHaruka Chealsea
# Haruka Chealsea
# Your band name could be Klaten Haruka Chealsea
